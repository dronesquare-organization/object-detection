# %% [markdown]
# <a href="https://colab.research.google.com/github/dronesquare-organization/object-detection/blob/main/valid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 학습된 모델 사용하기

# %% [markdown]
# ### 1. 레포지토리 클론

# %%
# !git clone https://github.com/dronesquare-organization/object-detection.git
# Out:
# Cloning into 'object-detection'...
# remote: Enumerating objects: 2986, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 2986 (delta 51), reused 147 (delta 43), pack-reused 2825
# Receiving objects: 100% (2986/2986), 116.54 MiB | 19.82 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# Updating files: 100% (2927/2927), done.
# Filtering content: 100% (4/4), 392.99 MiB | 55.73 MiB/s, done.

# %% [markdown]
# ### 모델 파일 업로드

# %%
from google.colab import files
from pathlib import Path
from IPython.display import Image

files.upload() # 학습을 통해 나온 모델 .pt 파일을 업로드
# Out:
#      <input type="file" id="files-a0d0f01c-9e28-4bf7-869b-bcc122ca455f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0d0f01c-9e28-4bf7-869b-bcc122ca455f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 모델 실행

# %%
val_img_path = Path("/content/object-detection/data/roboflow/valid/images/69_jpg.rf.4d510cba3cb9fe50f901d84b79a06485.jpg")

# !python /content/object-detection/yolov9/detect.py --weights /content/best.pt --img 640 --conf 0.5 --exist-ok --source "{val_img_path}"

Image(filename=f"/content/object-detection/yolov9/runs/detect/exp/{val_img_path.name}", width=640)
# Out:
# detect: weights=['/content/best.pt'], source=/content/object-detection/data/roboflow/valid/images/69_jpg.rf.4d510cba3cb9fe50f901d84b79a06485.jpg, data=object-detection/yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=object-detection/yolov9/runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/object-detection/yolov9/requirements.txt not found, check failed.
# YOLOv5 🚀 2024-4-3 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients
# image 1/1 /content/object-detection/data/roboflow/valid/images/69_jpg.rf.4d510cba3cb9fe50f901d84b79a06485.jpg: 640x640 7 Potholes, 2311.9ms
# ...

# %%
val_img_path = Path("/content/object-detection/data/roboflow/valid/images/194_jpg.rf.004aae7f270b8af593c5db899cc3496c.jpg")

# !python /content/object-detection/yolov9/detect.py --weights /content/best.pt --img 640 --conf 0.5 --exist-ok --source "{val_img_path}"

Image(filename=f"/content/object-detection/yolov9/runs/detect/exp/{val_img_path.name}", width=640)
# Out:
# detect: weights=['/content/best.pt'], source=/content/object-detection/data/roboflow/valid/images/194_jpg.rf.004aae7f270b8af593c5db899cc3496c.jpg, data=object-detection/yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=object-detection/yolov9/runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/object-detection/yolov9/requirements.txt not found, check failed.
# YOLOv5 🚀 2024-4-3 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients
# image 1/1 /content/object-detection/data/roboflow/valid/images/194_jpg.rf.004aae7f270b8af593c5db899cc3496c.jpg: 640x640 2 Potholes, 2500.7ms
# ...

# %%
val_img_path = Path("/content/object-detection/data/roboflow/valid/images/121_jpg.rf.2e55953d8630db5ee4fe9f80ca9686dd.jpg")

# !python /content/object-detection/yolov9/detect.py --weights /content/best.pt --img 640 --conf 0.5 --exist-ok --source "{val_img_path}"

Image(filename=f"/content/object-detection/yolov9/runs/detect/exp/{val_img_path.name}", width=640)
# Out:
# detect: weights=['/content/best.pt'], source=/content/object-detection/data/roboflow/valid/images/121_jpg.rf.2e55953d8630db5ee4fe9f80ca9686dd.jpg, data=object-detection/yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=object-detection/yolov9/runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/object-detection/yolov9/requirements.txt not found, check failed.
# YOLOv5 🚀 2024-4-3 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients
# image 1/1 /content/object-detection/data/roboflow/valid/images/121_jpg.rf.2e55953d8630db5ee4fe9f80ca9686dd.jpg: 640x640 1 Pothole, 3203.9ms
# ...

# %%
val_img_path = Path("/content/object-detection/data/roboflow/valid/images/127_jpg.rf.a10bea07d82441655cae064a0c0d1e61.jpg")

# !python /content/object-detection/yolov9/detect.py --weights /content/best.pt --img 640 --conf 0.5 --exist-ok --source "{val_img_path}"

Image(filename=f"/content/object-detection/yolov9/runs/detect/exp/{val_img_path.name}", width=640)
# Out:
# detect: weights=['/content/best.pt'], source=/content/object-detection/data/roboflow/valid/images/127_jpg.rf.a10bea07d82441655cae064a0c0d1e61.jpg, data=object-detection/yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=object-detection/yolov9/runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/object-detection/yolov9/requirements.txt not found, check failed.
# YOLOv5 🚀 2024-4-3 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients
# image 1/1 /content/object-detection/data/roboflow/valid/images/127_jpg.rf.a10bea07d82441655cae064a0c0d1e61.jpg: 640x640 4 Potholes, 2377.6ms
# ...
